# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# %% [markdown]
# #Sequential API

# %%
# Building the model using sequential API
# Define the input and output dimensions
input_dims=X_train.shape[1] #number of features
output_dims=10

model=Sequential()

model.add(tf.keras.Input(shape=(input_dims,),name='input_layer'))

model.add(Dense(512,activation='sigmoid',name='hidden_layer_1'))
model.add(Dense(128,activation='sigmoid',name='hidden_layer_2'))

#Add the output layer
model.add(Dense(output_dims,activation='softmax',name='output_layer'))

# %%
#Plotting the model
from tensorflow.keras.utils import plot_model
plot_model(model)

# %% [markdown]
# #Functional API

# %%
from tensorflow.keras import Model

# %%
from os import X_OK
# Define the input and output
input_dims = X_train.shape[1]
output_dims=10

#Create the input layers
inputlayer=tf.keras.Input(shape=(input_dims,),name='input_layer')

#create the dense layer
hiddenLayer1=Dense(512,activation='sigmoid',name='hidden_layer1')(inputlayer)
hiddenLayer2=Dense(128,activation='sigmoid',name='hidden_layer2')(hiddenLayer1)
outputlayer=Dense(output_dims,activation='softmax',name='output_layer')(hiddenLayer2)

# Define the Model
model=Model(inputs=inputlayer,outputs=outputlayer)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %% [markdown]
# # Compile a Neural Network

# %%
#compile the model
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# # Training a neural network

# %%
#define the batch_size and number of epochs
batch_size=128 #batch_size should always be in the form of 2^n where n=1,2,3,4...............
num_epochs=20

#Fit a neural network or train a neural network
history=model.fit(X_train,y_train,validation_split=0.2,epochs=num_epochs,batch_size=batch_size,verbose=1)

# %% [markdown]
# #Evaluate a train Network

# %%
#Evaluating our neural network using test dataset
score=model.evaluate(X_test,y_test,verbose=0)
print('Test score',score[0])
print('Test Accuracy',score[1])

# %% [markdown]
# # Inference or predictions using a trained neural network

# %%
#Prediction on test dataset using predict() function
y_pred=model.predict(X_test)
